# %% [markdown]
# <a href="https://colab.research.google.com/github/farrelandika/PCVK_Genap_2021/blob/main/Modul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/drive')
from skimage import io

img = cv.imread('/content/drive/MyDrive/PCVK/WhatsApp Image 2026-09-01 at 4.54.04 PM.jpeg')
cv2_imshow(img)

print ("Resolusi gambar", img.shape[1], "x", img.shape[0])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=1599x899>
# Resolusi gambar 1599 x 899

# %%
# Menampilkan gambar dengan format bgr
img = cv.imread('/content/drive/MyDrive/PCVK/WhatsApp Image 2026-09-01 at 4.54.04 PM.jpeg')
plt.imshow(img)

# %%
# konversi channel BGR -> RGB
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# Menampilkan citra geayscale
img_gray = cv.imread('/content/drive/MyDrive/PCVK/WhatsApp Image 2026-09-01 at 4.54.04 PM.jpeg', cv.IMREAD_GRAYSCALE)
#Tanpa cmap
plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title('dengan cmap')
#Dengan cmap
plt.subplot(1,2,2)
plt.imshow(img_gray, cmap='gray')
plt.title('tanpa cmap')
# Out:
# Text(0.5, 1.0, 'tanpa cmap')

# %%
#apabila menggunakan magma
plt.imshow(img_gray, cmap='magma')

# %%
#Melakukan Resizing
imgRGB = cv.cvtColor(img,cv.COLOR_BGR2RGB) #Konversi BGR ke RGB
img_output = cv.resize(imgRGB, (347, 229))
plt.imshow(img_output)

# %%
# Melakukan Flipping
img_flip = cv.flip(imgRGB, 1)
plt.imshow(img_flip)

# %%
from matplotlib import axes
# Memperbesar ukuran canvas dengan posisi gambar flipped
imgFlip=cv.flip(img_output,1)

#Tampilkan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(1,1,1)
ax.imshow(imgFlip)

# %%
#Membuat bentuk geometri 2D dari opencv diawali dengan pembuatan black image dengan tipe data int 16
black_img = np.zeros((530,530,3), dtype=np.int16)
plt

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#Membuat bentuk geometri 2D dari opencv diawali dengan pembuatan black image dengan tipe data int 16
black_img = np.zeros((530,530,3), dtype=np.int16)

#Tambahkan bentuk persegi panjang sesuai kordinat pt1 dan pt2
cv.rectangle(black_img,pt1=(290,0), pt2=(520,130), color=(0,0,255), thickness=10)
plt.imshow(black_img)

# %%
#Tambahkan persegi
cv.rectangle(black_img,pt1=(250,250), pt2=(350,350), color=(255,0,0), thickness=15)
plt.imshow(black_img)

# %%
#Tambahkan Lingkaran dan garis
cv.circle(black_img, center=(400,400), radius=50, color=(0,255,0), thickness=-1)
cv.line(black_img, pt1=(0,0), pt2=(530,530), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
#Penambahan Text
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='PCVK is fun', org=(10,500), fontFace=font, fontScale=2, color=(255,255,0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
#Penambahan lingkaran
cv.circle(black_img, center=(150,150), radius=50, color=(0,255,0), thickness=8)
plt.imshow(black_img)

# %%
#Pembuatan black image kembali dengan tipe data int 32
black_img2=np.zeros(shape=(530,530,3), dtype=np.int32)
plt.imshow(black_img2)
